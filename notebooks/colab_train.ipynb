# %% [markdown]
# # Group 9 Colab Training (T4)
# This notebook runs the full baseline training pipeline.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/aaditya-golash/cosc-419-.git /content/COSC-419-
# %cd /content/COSC-419-
# !pip install -e ./soccernet-0.1.62/
# !pip install pyyaml tqdm numpy pillow scikit-learn

# %%
# !nvidia-smi

# %%
DATA_ROOT = '/content/drive/MyDrive/SoccerNet/jersey-2023'
OUTPUT_DIR = '/content/drive/MyDrive/COSC419_runs/group9_run1'

# %%
# !python src/train_full.py --config configs/train_colab.yaml --data_root "$DATA_ROOT" --output_dir "$OUTPUT_DIR"
